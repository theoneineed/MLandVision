# %%
#Nabin Chapagain
#1001551151


#neural_network(<training_file>, <test_file>, <layers>, <units_per_layer>, <rounds>)

# Importing all needed libraries
import numpy as np
import math
import sys
import random

fname = 'yeast_training.txt'
fname1 = 'yeast_test.txt'
no_layers = 3
if(no_layers<2):
    print('The minimum number of layers should be 2 including input and output layer.\n\n')
    exit()
eta = 1
Unitspl = 11
#units_per_layer = how many perceptrons to place at each HIDDEN layer
#Note that this number is not applicable either to the input layer or to the output layer

rounds = 4
#rounds is the number of training rounds that you should use
#Each training round consists of using the whole training set once (i.e., using each training example once to update the weights)


mat_train = np.loadtxt(fname)
mat_test= np.loadtxt(fname1)

train_max = mat_train[:,0:-1].max()

no_train_mat_row = len(mat_train) 
no_train_mat_col = len(mat_train[0])

for i in range(no_train_mat_row):
    for j in range(no_train_mat_col-1):
        mat_train[i][j] = mat_train[i][j]/train_max

#print(mat_test,"\n\n\n\n\n\n")

for i in range(len(mat_test)):
    for j in range(no_train_mat_col-1):
        mat_test[i][j] = mat_test[i][j]/train_max
        
#print(mat_test)

# %%
"""
Training Phase

"""

train_mat_uniq = np.unique(mat_train[:,-1])
#This gives us a vector with s-values

random.seed()

Dim = max((no_train_mat_col-1),Unitspl,len(train_mat_uniq))

wt = np.zeros((no_layers, Unitspl, Dim))
bias = np.zeros((no_layers, Dim))


units2b_used=0

# %%
def sigmoid(x):
    sig = 1/(1+ np.exp(-x))
    return sig

# %%
for i in range (0,no_layers):
    for j in range (0,Unitspl):
        for k in range(0,Unitspl):
            wt[i][j][k]= (random.random()/20)*(random.randrange(-1,1))



for i in range(0,no_layers):
    for j in range(0,Unitspl):
        bias[i][j] = (random.random()/20)*(random.randrange(-1,1))

# %%
for l in range(0,rounds):
    print("Round",l, "starting: \n\n\n\n\n\n\n")
    #browsing through each individual row of train_mat
    for i  in range(0, no_train_mat_row):
        t= np.zeros(len(train_mat_uniq))
        #we are making a test vector here
        for j in range(0,len(train_mat_uniq)):
            if(mat_train[i][-1]==train_mat_uniq[j]):
                t[j]=1
            t_t = t.T #transpose of hot_vector
            
        z_output = np.zeros((no_layers, Dim))
        #print(z_output)
        
        
        for j in range(0,no_train_mat_col-1):
            z_output[0][j]=mat_train[i][j]
        
        a_wtdsum = np.zeros((no_layers, Unitspl))
        
        
        for j in range(1,no_layers):
            for k in range(0,Unitspl):
                wtd_sum =bias[j][k]
                #print(wtd_sum)
                
                if((j-1) != 0):
                    for m in range(0,Unitspl):
                        wtd_sum += wt[j][k][m]*z_output[j-1][m] 
                        
                elif((j -1)==0):
                     for m in range(0,no_train_mat_col-1):
                        wtd_sum += wt[j][k][m]*z_output[j-1][m]
                
                #print(wtd_sum)
                a_wtdsum[j][k] = wtd_sum
                
                
                
                z_output[j][k] = sigmoid(a_wtdsum[j][k])
            #print(z_output)
        #now to compute new delta values
        delta = np.zeros((no_layers, Unitspl))
        
        for j in range(0,len(train_mat_uniq)):
            delta[no_layers-1][j]= (z_output[no_layers-1][j] - t[j]) * z_output[no_layers-1][j] * (1-z_output[no_layers-1][j])
            
        
        for j in range(no_layers-2, 0,-1):
            for k in range(0,Unitspl):
                #delta[j][k]
                del_in =0
                if (j+1 == no_layers-1):
                    units2b_used = len(train_mat_uniq)
                else:
                    units2b_used = Unitspl
                
                for looping in range(0,units2b_used):
                    del_in += delta[j+1][looping] * wt[j+1][looping][k]
                delta[j][k] = del_in *z_output[j][k] * (1 - z_output[j][k])
        #print(delta)
        
        units2b_used = 0
        for j in range(1,no_layers):
            
            if(j==no_layers-1):
                units2b_used = len(train_mat_uniq)
            else:
                units2b_used = Unitspl
            
            for m in range(0,units2b_used):
                bias[j][m] = bias[j][m] - eta * delta[j][m]
                
                units_loop = 0
                if (j-1 == 0):
                    units_loop = no_train_mat_col-1
                else:
                    units_loop = Unitspl      
                
                for n in range (0, units_loop):
                    wt[j][m][n] = wt[j][m][n] - eta * delta[j][m]* z_output[j-1][n]
                    
            #print(wt)
    eta*=0.98
# Out:
# Round 0 starting:
#
#
#
#
#
#
#
# Round 1 starting:
#
#
#
#
#
#
#
# Round 2 starting:
#
#
#
#
#
#
#
# Round 3 starting:

# %%
"""
Classification Phase
"""
av_acc=0

test_mat_uniq = np.unique(mat_test[:,-1])
#print(test_mat_uniq)

        
for i in range(0,len(mat_test)):
    t= np.zeros(len(test_mat_uniq))
    #we are making a test vector here
    
    z_output = np.zeros((no_layers, Dim))
    
    for j in range(0,no_train_mat_col-1):
        z_output[0][j]=mat_test[i][j]
        
    a_wtdsum = np.zeros((no_layers, Unitspl))
    
    for j in range(1,no_layers):
        if(j==no_layers-1):
            Units2b_used = len(test_mat_uniq)
        else:
            Units2b_used = Unitspl
        for k in range(0,Units2b_used):
            wtd_sum =bias[j][k]
            
            if((j-1) != 0):
                for m in range(0,Unitspl):
                    wtd_sum += wt[j][k][m]*z_output[j-1][m] 
                        
            elif((j -1)==0):
                for m in range(0,no_train_mat_col-1):
                    wtd_sum += wt[j][k][m]*z_output[j-1][m]
                
            a_wtdsum[j][k] = wtd_sum
                
                
            z_output[j][k] = sigmoid(a_wtdsum[j][k])
    #print(z_output[no_layers-1],"\n\n\n\n\n\n\n")
    
    object_id = i+1
    predicted_class_index = np.where(z_output[no_layers-1] == z_output[no_layers-1].max())
    predicted_class = (test_mat_uniq[predicted_class_index[0][0]])
    
    accuracy = 0
    #print(predicted_class,"\n\n\n",z_output[no_layers-1],"\n\n\n\n\n",mat_test[i][-1])
    true_class = mat_test[i][-1]
    #print(true_class)
    if(predicted_class == true_class):
        accuracy=1
    #print(predicted_class[0])
    
    print('ID=%5d, predicted=%3d, true=%3d, accuracy=%4.2f\n'%(object_id, predicted_class, true_class, accuracy));
    av_acc+=accuracy 
av_acc = av_acc/len(mat_test)

print('classification accuracy=%6.4f\n'% av_acc);
# Out:
# ID=    1, predicted=  7, true=  3, accuracy=0.00
#
# ID=    2, predicted=  7, true=  7, accuracy=1.00
#
# ID=    3, predicted=  7, true=  7, accuracy=1.00
#
# ID=    4, predicted=  7, true=  2, accuracy=0.00
#
# ID=    5, predicted=  7, true=  2, accuracy=0.00
#
# ID=    6, predicted=  7, true=  2, accuracy=0.00
#
# ID=    7, predicted=  7, true=  7, accuracy=1.00
#
# ID=    8, predicted=  7, true=  1, accuracy=0.00
#
# ID=    9, predicted=  7, true=  7, accuracy=1.00
#
# ID=   10, predicted=  7, true=  7, accuracy=1.00
#
# ID=   11, predicted=  7, true=  3, accuracy=0.00
#
# ID=   12, predicted=  7, true=  6, accuracy=0.00
#
# ID=   13, predicted=  7, true=  2, accuracy=0.00
#
# ID=   14, predicted=  7, true=  5, accuracy=0.00
#
# ID=   15, predicted=  1, true=  5, accuracy=0.00
#
# ID=   16, predicted=  7, true=  7, accuracy=1.00
#
# ID=   17, predicted=  7, true=  3, accuracy=0.00
#
# ID=   18, predicted=  7, true=  2, accuracy=0.00
#
# ID=   19, predicted=  7, true=  3, accuracy=0.00
#
# ID=   20, predicted=  7, true=  2, accuracy=0.00
#
# ID=   21, predicted=  7, true=  2, accuracy=0.00
#
# ID=   22, predicted=  7, true=  3, accuracy=0.00
#
# ID=   23, predicted=  7, true=  2, accuracy=0.00
#
# ID=   24, predicted=  7, true=  5, accuracy=0.00
#
# ID=   25, predicted=  7, true=  3, accuracy=0.00
#
# ID=   26, predicted=  7, true=  2, accuracy=0.00
#
# ID=   27, predicted=  7, true=  2, accuracy=0.00
#
# ID=   28, predicted=  7, true=  7, accuracy=1.00
#
# ID=   29, predicted=  7, true=  3, accuracy=0.00
#
# ID=   30, predicted=  7, true=  9, accuracy=0.00
#
# ID=   31, predicted=  7, true=  7, accuracy=1.00
#
# ID=   32, predicted=  7, true=  7, accuracy=1.00
#
# ID=   33, predicted=  7, true=  7, accuracy=1.00
#
# ID=   34, predicted=  1, true=  1, accuracy=1.00
#
# ID=   35, predicted=  7, true=  7, accuracy=1.00
#
# ID=   36, predicted=  7, true=  3, accuracy=0.00
#
# ID=   37, predicted=  7, true=  3, accuracy=0.00
#
# ID=   38, predicted=  7, true=  2, accuracy=0.00
#
# ID=   39, predicted=  7, true=  7, accuracy=1.00
#
# ID=   40, predicted=  7, true=  7, accuracy=1.00
#
# ID=   41, predicted=  7, true=  3, accuracy=0.00
#
# ID=   42, predicted=  7, true=  9, accuracy=0.00
#
# ID=   43, predicted=  7, true=  1, accuracy=0.00
#
# ID=   44, predicted=  7, true=  2, accuracy=0.00
#
# ID=   45, predicted=  7, true=  2, accuracy=0.00
#
# ID=   46, predicted=  7, true=  2, accuracy=0.00
#
# ID=   47, predicted=  7, true=  7, accuracy=1.00
#
# ID=   48, predicted=  1, true=  1, accuracy=1.00
#
# ID=   49, predicted=  7, true=  1, accuracy=0.00
#
# ID=   50, predicted=  7, true=  1, accuracy=0.00
#
# ID=   51, predicted=  7, true=  7, accuracy=1.00
#
# ID=   52, predicted=  7, true=  7, accuracy=1.00
#
# ID=   53, predicted=  7, true=  2, accuracy=0.00
#
# ID=   54, predicted=  7, true=  2, accuracy=0.00
#
# ID=   55, predicted=  7, true=  7, accuracy=1.00
#
# ID=   56, predicted=  7, true=  2, accuracy=0.00
#
# ID=   57, predicted=  7, true=  2, accuracy=0.00
#
# ID=   58, predicted=  7, true=  2, accuracy=0.00
#
# ID=   59, predicted=  1, true=  3, accuracy=0.00
#
# ID=   60, predicted=  7, true=  3, accuracy=0.00
#
# ID=   61, predicted=  7, true=  2, accuracy=0.00
#
# ID=   62, predicted=  7, true=  2, accuracy=0.00
#
# ID=   63, predicted=  7, true=  1, accuracy=0.00
#
# ID=   64, predicted=  7, true=  8, accuracy=0.00
#
# ID=   65, predicted=  7, true=  3, accuracy=0.00
#
# ID=   66, predicted=  7, true=  9, accuracy=0.00
#
# ID=   67, predicted=  7, true=  2, accuracy=0.00
#
# ID=   68, predicted=  7, true=  8, accuracy=0.00
#
# ID=   69, predicted=  7, true=  7, accuracy=1.00
#
# ID=   70, predicted=  7, true=  2, accuracy=0.00
#
# ID=   71, predicted=  7, true=  9, accuracy=0.00
#
# ID=   72, predicted=  7, true=  2, accuracy=0.00
#
# ID=   73, predicted=  7, true=  3, accuracy=0.00
#
# ID=   74, predicted=  7, true=  7, accuracy=1.00
#
# ID=   75, predicted=  7, true=  7, accuracy=1.00
#
# ID=   76, predicted=  7, true=  9, accuracy=0.00
#
# ID=   77, predicted=  1, true=  3, accuracy=0.00
#
# ID=   78, predicted=  7, true=  7, accuracy=1.00
#
# ID=   79, predicted=  7, true=  8, accuracy=0.00
#
# ID=   80, predicted=  7, true=  7, accuracy=1.00
#
# ID=   81, predicted=  7, true=  7, accuracy=1.00
#
# ID=   82, predicted=  1, true=  5, accuracy=0.00
#
# ID=   83, predicted=  7, true=  5, accuracy=0.00
#
# ID=   84, predicted=  7, true=  7, accuracy=1.00
#
# ID=   85, predicted=  7, true=  1, accuracy=0.00
#
# ID=   86, predicted=  1, true=  4, accuracy=0.00
#
# ID=   87, predicted=  7, true=  7, accuracy=1.00
#
# ID=   88, predicted=  7, true=  3, accuracy=0.00
#
# ID=   89, predicted=  7, true=  2, accuracy=0.00
#
# ID=   90, predicted=  7, true=  7, accuracy=1.00
#
# ID=   91, predicted=  7, true=  7, accuracy=1.00
#
# ID=   92, predicted=  7, true=  7, accuracy=1.00
#
# ID=   93, predicted=  7, true=  7, accuracy=1.00
#
# ID=   94, predicted=  1, true=  1, accuracy=1.00
#
# ID=   95, predicted=  7, true=  2, accuracy=0.00
#
# ID=   96, predicted=  7, true=  2, accuracy=0.00
#
# ID=   97, predicted=  1, true=  1, accuracy=1.00
#
# ID=   98, predicted=  7, true=  2, accuracy=0.00
#
# ID=   99, predicted=  7, true=  7, accuracy=1.00
#
# ID=  100, predicted=  7, true=  2, accuracy=0.00
#
# ID=  101, predicted=  7, true=  3, accuracy=0.00
#
# ID=  102, predicted=  7, true=  3, accuracy=0.00
#
# ID=  103, predicted=  7, true=  2, accuracy=0.00
#
# ID=  104, predicted=  7, true=  7, accuracy=1.00
#
# ID=  105, predicted=  7, true=  3, accuracy=0.00
#
# ID=  106, predicted=  7, true=  9, accuracy=0.00
#
# ID=  107, predicted=  7, true=  6, accuracy=0.00
#
# ID=  108, predicted=  7, true=  7, accuracy=1.00
#
# ID=  109, predicted=  7, true=  7, accuracy=1.00
#
# ID=  110, predicted=  7, true=  1, accuracy=0.00
#
# ID=  111, predicted=  1, true=  2, accuracy=0.00
#
# ID=  112, predicted=  7, true=  2, accuracy=0.00
#
# ID=  113, predicted=  7, true=  7, accuracy=1.00
#
# ID=  114, predicted=  7, true=  1, accuracy=0.00
#
# ID=  115, predicted=  7, true=  7, accuracy=1.00
#
# ID=  116, predicted=  7, true=  2, accuracy=0.00
#
# ID=  117, predicted=  7, true=  2, accuracy=0.00
#
# ID=  118, predicted=  7, true=  8, accuracy=0.00
#
# ID=  119, predicted=  7, true=  5, accuracy=0.00
#
# ID=  120, predicted=  7, true=  2, accuracy=0.00
#
# ID=  121, predicted=  7, true=  7, accuracy=1.00
#
# ID=  122, predicted=  7, true=  2, accuracy=0.00
#
# ID=  123, predicted=  7, true=  4, accuracy=0.00
#
# ID=  124, predicted=  7, true=  7, accuracy=1.00
#
# ID=  125, predicted=  1, true=  1, accuracy=1.00
#
# ID=  126, predicted=  7, true=  7, accuracy=1.00
#
# ID=  127, predicted=  7, true=  7, accuracy=1.00
#
# ID=  128, predicted=  7, true=  7, accuracy=1.00
#
# ID=  129, predicted=  7, true=  7, accuracy=1.00
#
# ID=  130, predicted=  7, true=  2, accuracy=0.00
#
# ID=  131, predicted=  7, true=  7, accuracy=1.00
#
# ID=  132, predicted=  7, true=  2, accuracy=0.00
#
# ID=  133, predicted=  7, true=  2, accuracy=0.00
#
# ID=  134, predicted=  7, true=  2, accuracy=0.00
#
# ID=  135, predicted=  1, true=  1, accuracy=1.00
#
# ID=  136, predicted=  7, true=  7, accuracy=1.00
#
# ID=  137, predicted=  7, true=  8, accuracy=0.00
#
# ID=  138, predicted=  7, true=  3, accuracy=0.00
#
# ID=  139, predicted=  7, true=  2, accuracy=0.00
#
# ID=  140, predicted=  7, true=  2, accuracy=0.00
#
# ID=  141, predicted=  7, true=  7, accuracy=1.00
#
# ID=  142, predicted=  7, true=  2, accuracy=0.00
#
# ID=  143, predicted=  7, true=  3, accuracy=0.00
#
# ID=  144, predicted=  1, true=  1, accuracy=1.00
#
# ID=  145, predicted=  7, true=  7, accuracy=1.00
#
# ID=  146, predicted=  7, true=  2, accuracy=0.00
#
# ID=  147, predicted=  7, true=  2, accuracy=0.00
#
# ID=  148, predicted=  7, true=  1, accuracy=0.00
#
# ID=  149, predicted=  7, true=  2, accuracy=0.00
#
# ID=  150, predicted=  7, true=  2, accuracy=0.00
#
# ID=  151, predicted=  7, true=  7, accuracy=1.00
#
# ID=  152, predicted=  7, true=  2, accuracy=0.00
#
# ID=  153, predicted=  7, true=  2, accuracy=0.00
#
# ID=  154, predicted=  7, true=  1, accuracy=0.00
#
# ID=  155, predicted=  7, true=  5, accuracy=0.00
#
# ID=  156, predicted=  7, true=  2, accuracy=0.00
#
# ID=  157, predicted=  7, true=  7, accuracy=1.00
#
# ID=  158, predicted=  7, true=  7, accuracy=1.00
#
# ID=  159, predicted=  7, true=  7, accuracy=1.00
#
# ID=  160, predicted=  7, true=  2, accuracy=0.00
#
# ID=  161, predicted=  7, true=  7, accuracy=1.00
#
# ID=  162, predicted=  7, true=  1, accuracy=0.00
#
# ID=  163, predicted=  7, true=  2, accuracy=0.00
#
# ID=  164, predicted=  1, true=  1, accuracy=1.00
#
# ID=  165, predicted=  1, true=  4, accuracy=0.00
#
# ID=  166, predicted=  7, true=  7, accuracy=1.00
#
# ID=  167, predicted=  7, true=  7, accuracy=1.00
#
# ID=  168, predicted=  7, true=  2, accuracy=0.00
#
# ID=  169, predicted=  7, true=  2, accuracy=0.00
#
# ID=  170, predicted=  7, true=  1, accuracy=0.00
#
# ID=  171, predicted=  1, true=  1, accuracy=1.00
#
# ID=  172, predicted=  1, true=  4, accuracy=0.00
#
# ID=  173, predicted=  1, true=  1, accuracy=1.00
#
# ID=  174, predicted=  7, true=  7, accuracy=1.00
#
# ID=  175, predicted=  7, true=  2, accuracy=0.00
#
# ID=  176, predicted=  7, true=  7, accuracy=1.00
#
# ID=  177, predicted=  7, true=  2, accuracy=0.00
#
# ID=  178, predicted=  1, true=  1, accuracy=1.00
#
# ID=  179, predicted=  7, true=  7, accuracy=1.00
#
# ID=  180, predicted=  7, true=  7, accuracy=1.00
#
# ID=  181, predicted=  1, true=  4, accuracy=0.00
#
# ID=  182, predicted=  7, true=  3, accuracy=0.00
#
# ID=  183, predicted=  7, true=  3, accuracy=0.00
#
# ID=  184, predicted=  7, true=  2, accuracy=0.00
#
# ID=  185, predicted=  7, true=  2, accuracy=0.00
#
# ID=  186, predicted=  7, true=  7, accuracy=1.00
#
# ID=  187, predicted=  7, true=  3, accuracy=0.00
#
# ID=  188, predicted=  7, true=  7, accuracy=1.00
#
# ID=  189, predicted=  7, true=  2, accuracy=0.00
#
# ID=  190, predicted=  1, true=  1, accuracy=1.00
#
# ID=  191, predicted=  7, true=  7, accuracy=1.00
#
# ID=  192, predicted=  7, true=  7, accuracy=1.00
#
# ID=  193, predicted=  7, true=  7, accuracy=1.00
#
# ID=  194, predicted=  1, true=  9, accuracy=0.00
#
# ID=  195, predicted=  7, true=  1, accuracy=0.00
#
# ID=  196, predicted=  7, true=  2, accuracy=0.00
#
# ID=  197, predicted=  7, true=  2, accuracy=0.00
#
# ID=  198, predicted=  7, true=  3, accuracy=0.00
#
# ID=  199, predicted=  7, true=  7, accuracy=1.00
#
# ID=  200, predicted=  7, true=  7, accuracy=1.00
#
# ID=  201, predicted=  7, true=  1, accuracy=0.00
#
# ID=  202, predicted=  7, true=  3, accuracy=0.00
#
# ID=  203, predicted=  7, true=  2, accuracy=0.00
#
# ID=  204, predicted=  7, true=  7, accuracy=1.00
#
# ID=  205, predicted=  7, true=  3, accuracy=0.00
#
# ID=  206, predicted=  7, true=  3, accuracy=0.00
#
# ID=  207, predicted=  7, true=  7, accuracy=1.00
#
# ID=  208, predicted=  7, true=  1, accuracy=0.00
#
# ID=  209, predicted=  7, true=  3, accuracy=0.00
#
# ID=  210, predicted=  7, true=  2, accuracy=0.00
#
# ID=  211, predicted=  7, true=  3, accuracy=0.00
#
# ID=  212, predicted=  7, true=  2, accuracy=0.00
#
# ID=  213, predicted=  7, true=  1, accuracy=0.00
#
# ID=  214, predicted=  7, true=  1, accuracy=0.00
#
# ID=  215, predicted=  7, true=  7, accuracy=1.00
#
# ID=  216, predicted=  7, true=  2, accuracy=0.00
#
# ID=  217, predicted=  1, true=  1, accuracy=1.00
#
# ID=  218, predicted=  7, true=  3, accuracy=0.00
#
# ID=  219, predicted=  1, true=  1, accuracy=1.00
#
# ID=  220, predicted=  1, true=  1, accuracy=1.00
#
# ID=  221, predicted=  7, true=  2, accuracy=0.00
#
# ID=  222, predicted=  7, true=  7, accuracy=1.00
#
# ID=  223, predicted=  7, true=  3, accuracy=0.00
#
# ID=  224, predicted=  1, true=  1, accuracy=1.00
#
# ID=  225, predicted=  1, true=  8, accuracy=0.00
#
# ID=  226, predicted=  7, true=  7, accuracy=1.00
#
# ID=  227, predicted=  1, true=  1, accuracy=1.00
#
# ID=  228, predicted=  7, true=  7, accuracy=1.00
#
# ID=  229, predicted=  7, true=  9, accuracy=0.00
#
# ID=  230, predicted=  7, true=  1, accuracy=0.00
#
# ID=  231, predicted=  7, true=  1, accuracy=0.00
#
# ID=  232, predicted=  1, true=  7, accuracy=0.00
#
# ID=  233, predicted=  7, true=  3, accuracy=0.00
#
# ID=  234, predicted=  7, true=  7, accuracy=1.00
#
# ID=  235, predicted=  7, true=  1, accuracy=0.00
#
# ID=  236, predicted=  7, true=  2, accuracy=0.00
#
# ID=  237, predicted=  7, true=  7, accuracy=1.00
#
# ID=  238, predicted=  7, true=  1, accuracy=0.00
#
# ID=  239, predicted=  7, true=  4, accuracy=0.00
#
# ID=  240, predicted=  7, true=  3, accuracy=0.00
#
# ID=  241, predicted=  7, true=  7, accuracy=1.00
#
# ID=  242, predicted=  7, true=  7, accuracy=1.00
#
# ID=  243, predicted=  1, true=  3, accuracy=0.00
#
# ID=  244, predicted=  7, true=  8, accuracy=0.00
#
# ID=  245, predicted=  7, true=  2, accuracy=0.00
#
# ID=  246, predicted=  7, true=  7, accuracy=1.00
#
# ID=  247, predicted=  7, true=  2, accuracy=0.00
#
# ID=  248, predicted=  7, true=  1, accuracy=0.00
#
# ID=  249, predicted=  7, true=  7, accuracy=1.00
#
# ID=  250, predicted=  1, true=  1, accuracy=1.00
#
# ID=  251, predicted=  7, true=  9, accuracy=0.00
#
# ID=  252, predicted=  7, true=  3, accuracy=0.00
#
# ID=  253, predicted=  7, true=  1, accuracy=0.00
#
# ID=  254, predicted=  7, true=  7, accuracy=1.00
#
# ID=  255, predicted=  1, true=  1, accuracy=1.00
#
# ID=  256, predicted=  7, true=  4, accuracy=0.00
#
# ID=  257, predicted=  7, true=  3, accuracy=0.00
#
# ID=  258, predicted=  7, true=  2, accuracy=0.00
#
# ID=  259, predicted=  7, true=  1, accuracy=0.00
#
# ID=  260, predicted=  7, true=  3, accuracy=0.00
#
# ID=  261, predicted=  7, true=  2, accuracy=0.00
#
# ID=  262, predicted=  7, true=  2, accuracy=0.00
#
# ID=  263, predicted=  7, true=  4, accuracy=0.00
#
# ID=  264, predicted=  7, true=  9, accuracy=0.00
#
# ID=  265, predicted=  7, true=  2, accuracy=0.00
#
# ID=  266, predicted=  7, true=  2, accuracy=0.00
#
# ID=  267, predicted=  1, true=  4, accuracy=0.00
#
# ID=  268, predicted=  7, true=  7, accuracy=1.00
#
# ID=  269, predicted=  7, true=  7, accuracy=1.00
#
# ID=  270, predicted=  7, true=  7, accuracy=1.00
#
# ID=  271, predicted=  7, true=  7, accuracy=1.00
#
# ID=  272, predicted=  7, true=  7, accuracy=1.00
#
# ID=  273, predicted=  1, true=  8, accuracy=0.00
#
# ID=  274, predicted=  7, true=  2, accuracy=0.00
#
# ID=  275, predicted=  7, true=  2, accuracy=0.00
#
# ID=  276, predicted=  7, true=  7, accuracy=1.00
#
# ID=  277, predicted=  7, true=  3, accuracy=0.00
#
# ID=  278, predicted=  7, true=  2, accuracy=0.00
#
# ID=  279, predicted=  7, true=  1, accuracy=0.00
#
# ID=  280, predicted=  7, true=  2, accuracy=0.00
#
# ID=  281, predicted=  7, true=  7, accuracy=1.00
#
# ID=  282, predicted=  7, true=  7, accuracy=1.00
#
# ID=  283, predicted=  7, true=  2, accuracy=0.00
#
# ID=  284, predicted=  7, true=  7, accuracy=1.00
#
# ID=  285, predicted=  7, true=  2, accuracy=0.00
#
# ID=  286, predicted=  7, true=  7, accuracy=1.00
#
# ID=  287, predicted=  7, true=  2, accuracy=0.00
#
# ID=  288, predicted=  7, true=  7, accuracy=1.00
#
# ID=  289, predicted=  7, true=  3, accuracy=0.00
#
# ID=  290, predicted=  7, true=  2, accuracy=0.00
#
# ID=  291, predicted=  7, true=  3, accuracy=0.00
#
# ID=  292, predicted=  7, true=  5, accuracy=0.00
#
# ID=  293, predicted=  7, true=  2, accuracy=0.00
#
# ID=  294, predicted=  7, true=  7, accuracy=1.00
#
# ID=  295, predicted=  7, true=  8, accuracy=0.00
#
# ID=  296, predicted=  7, true=  1, accuracy=0.00
#
# ID=  297, predicted=  7, true=  3, accuracy=0.00
#
# ID=  298, predicted=  7, true=  2, accuracy=0.00
#
# ID=  299, predicted=  7, true=  7, accuracy=1.00
#
# ID=  300, predicted=  7, true=  1, accuracy=0.00
#
# ID=  301, predicted=  7, true=  7, accuracy=1.00
#
# ID=  302, predicted=  7, true=  1, accuracy=0.00
#
# ID=  303, predicted=  7, true=  1, accuracy=0.00
#
# ID=  304, predicted=  7, true=  3, accuracy=0.00
#
# ID=  305, predicted=  7, true=  2, accuracy=0.00
#
# ID=  306, predicted=  7, true=  2, accuracy=0.00
#
# ID=  307, predicted=  7, true=  7, accuracy=1.00
#
# ID=  308, predicted=  7, true=  8, accuracy=0.00
#
# ID=  309, predicted=  7, true=  7, accuracy=1.00
#
# ID=  310, predicted=  1, true=  1, accuracy=1.00
#
# ID=  311, predicted=  7, true=  3, accuracy=0.00
#
# ID=  312, predicted=  7, true=  7, accuracy=1.00
#
# ID=  313, predicted=  7, true=  1, accuracy=0.00
#
# ID=  314, predicted=  7, true=  7, accuracy=1.00
#
# ID=  315, predicted=  7, true=  7, accuracy=1.00
#
# ID=  316, predicted=  7, true=  7, accuracy=1.00
#
# ID=  317, predicted=  7, true=  7, accuracy=1.00
#
# ID=  318, predicted=  7, true=  7, accuracy=1.00
#
# ID=  319, predicted=  7, true=  3, accuracy=0.00
#
# ID=  320, predicted=  1, true=  1, accuracy=1.00
# ID=  321, predicted=  7, true=  9, accuracy=0.00
#
# ID=  322, predicted=  7, true=  7, accuracy=1.00
#
# ID=  323, predicted=  7, true=  7, accuracy=1.00
#
# ID=  324, predicted=  7, true=  3, accuracy=0.00
#
# ID=  325, predicted=  7, true=  5, accuracy=0.00
#
# ID=  326, predicted=  7, true=  2, accuracy=0.00
#
# ID=  327, predicted=  7, true=  2, accuracy=0.00
#
# ID=  328, predicted=  7, true=  7, accuracy=1.00
#
# ID=  329, predicted=  7, true=  3, accuracy=0.00
#
# ID=  330, predicted=  7, true=  1, accuracy=0.00
#
# ID=  331, predicted=  7, true=  7, accuracy=1.00
#
# ID=  332, predicted=  7, true=  5, accuracy=0.00
#
# ID=  333, predicted=  7, true=  2, accuracy=0.00
#
# ID=  334, predicted=  7, true=  7, accuracy=1.00
#
# ID=  335, predicted=  7, true=  2, accuracy=0.00
#
# ID=  336, predicted=  7, true=  6, accuracy=0.00
#
# ID=  337, predicted=  7, true=  2, accuracy=0.00
#
# ID=  338, predicted=  1, true=  2, accuracy=0.00
#
# ID=  339, predicted=  7, true=  9, accuracy=0.00
#
# ID=  340, predicted=  7, true=  7, accuracy=1.00
#
# ID=  341, predicted=  7, true=  9, accuracy=0.00
#
# ID=  342, predicted=  7, true=  3, accuracy=0.00
#
# ID=  343, predicted=  1, true=  5, accuracy=0.00
#
# ID=  344, predicted=  7, true=  5, accuracy=0.00
#
# ID=  345, predicted=  7, true=  2, accuracy=0.00
#
# ID=  346, predicted=  7, true=  2, accuracy=0.00
#
# ID=  347, predicted=  1, true=  2, accuracy=0.00
#
# ID=  348, predicted=  7, true=  1, accuracy=0.00
#
# ID=  349, predicted=  7, true=  2, accuracy=0.00
#
# ID=  350, predicted=  7, true=  2, accuracy=0.00
#
# ID=  351, predicted=  7, true=  7, accuracy=1.00
#
# ID=  352, predicted=  7, true=  7, accuracy=1.00
#
# ID=  353, predicted=  7, true=  7, accuracy=1.00
#
# ID=  354, predicted=  1, true=  6, accuracy=0.00
#
# ID=  355, predicted=  7, true=  1, accuracy=0.00
#
# ID=  356, predicted=  7, true=  1, accuracy=0.00
#
# ID=  357, predicted=  7, true=  2, accuracy=0.00
#
# ID=  358, predicted=  7, true=  7, accuracy=1.00
#
# ID=  359, predicted=  7, true=  7, accuracy=1.00
#
# ID=  360, predicted=  7, true=  7, accuracy=1.00
#
# ID=  361, predicted=  7, true=  3, accuracy=0.00
#
# ID=  362, predicted=  7, true=  7, accuracy=1.00
#
# ID=  363, predicted=  7, true=  2, accuracy=0.00
#
# ID=  364, predicted=  7, true=  2, accuracy=0.00
#
# ID=  365, predicted=  7, true=  7, accuracy=1.00
#
# ID=  366, predicted=  7, true=  7, accuracy=1.00
#
# ID=  367, predicted=  7, true=  2, accuracy=0.00
#
# ID=  368, predicted=  7, true=  6, accuracy=0.00
#
# ID=  369, predicted=  7, true=  2, accuracy=0.00
#
# ID=  370, predicted=  1, true=  1, accuracy=1.00
#
# ID=  371, predicted=  7, true=  3, accuracy=0.00
#
# ID=  372, predicted=  7, true=  2, accuracy=0.00
#
# ID=  373, predicted=  7, true=  2, accuracy=0.00
#
# ID=  374, predicted=  7, true=  7, accuracy=1.00
#
# ID=  375, predicted=  7, true=  2, accuracy=0.00
#
# ID=  376, predicted=  7, true=  2, accuracy=0.00
#
# ID=  377, predicted=  7, true=  3, accuracy=0.00
#
# ID=  378, predicted=  7, true=  7, accuracy=1.00
#
# ID=  379, predicted=  1, true=  7, accuracy=0.00
#
# ID=  380, predicted=  7, true=  2, accuracy=0.00
#
# ID=  381, predicted=  7, true=  1, accuracy=0.00
#
# ID=  382, predicted=  7, true=  7, accuracy=1.00
#
# ID=  383, predicted=  7, true=  1, accuracy=0.00
#
# ID=  384, predicted=  7, true=  4, accuracy=0.00
#
# ID=  385, predicted=  7, true=  1, accuracy=0.00
#
# ID=  386, predicted=  7, true=  7, accuracy=1.00
#
# ID=  387, predicted=  7, true=  5, accuracy=0.00
#
# ID=  388, predicted=  7, true=  2, accuracy=0.00
#
# ID=  389, predicted=  7, true=  7, accuracy=1.00
#
# ID=  390, predicted=  7, true=  1, accuracy=0.00
#
# ID=  391, predicted=  7, true=  7, accuracy=1.00
#
# ID=  392, predicted=  7, true=  7, accuracy=1.00
#
# ID=  393, predicted=  1, true=  2, accuracy=0.00
#
# ID=  394, predicted=  7, true=  7, accuracy=1.00
#
# ID=  395, predicted=  7, true=  7, accuracy=1.00
#
# ID=  396, predicted=  7, true=  2, accuracy=0.00
#
# ID=  397, predicted=  7, true=  3, accuracy=0.00
#
# ID=  398, predicted=  7, true=  7, accuracy=1.00
#
# ID=  399, predicted=  7, true=  2, accuracy=0.00
#
# ID=  400, predicted=  7, true=  2, accuracy=0.00
#
# ID=  401, predicted=  7, true=  7, accuracy=1.00
#
# ID=  402, predicted=  1, true=  1, accuracy=1.00
#
# ID=  403, predicted=  7, true=  2, accuracy=0.00
#
# ID=  404, predicted=  7, true=  7, accuracy=1.00
#
# ID=  405, predicted=  7, true=  2, accuracy=0.00
#
# ID=  406, predicted=  7, true=  3, accuracy=0.00
#
# ID=  407, predicted=  1, true= 10, accuracy=0.00
#
# ID=  408, predicted=  7, true=  2, accuracy=0.00
#
# ID=  409, predicted=  7, true=  3, accuracy=0.00
#
# ID=  410, predicted=  7, true=  2, accuracy=0.00
#
# ID=  411, predicted=  7, true=  3, accuracy=0.00
#
# ID=  412, predicted=  7, true=  3, accuracy=0.00
#
# ID=  413, predicted=  7, true=  7, accuracy=1.00
#
# ID=  414, predicted=  7, true=  7, accuracy=1.00
#
# ID=  415, predicted=  1, true=  5, accuracy=0.00
#
# ID=  416, predicted=  7, true=  3, accuracy=0.00
#
# ID=  417, predicted=  7, true=  5, accuracy=0.00
#
# ID=  418, predicted=  7, true=  1, accuracy=0.00
#
# ID=  419, predicted=  7, true=  2, accuracy=0.00
#
# ID=  420, predicted=  1, true=  1, accuracy=1.00
#
# ID=  421, predicted=  7, true=  7, accuracy=1.00
#
# ID=  422, predicted=  7, true=  2, accuracy=0.00
#
# ID=  423, predicted=  7, true=  3, accuracy=0.00
#
# ID=  424, predicted=  7, true=  2, accuracy=0.00
#
# ID=  425, predicted=  7, true=  7, accuracy=1.00
#
# ID=  426, predicted=  7, true=  3, accuracy=0.00
#
# ID=  427, predicted=  7, true=  7, accuracy=1.00
#
# ID=  428, predicted=  7, true=  7, accuracy=1.00
#
# ID=  429, predicted=  7, true=  7, accuracy=1.00
#
# ID=  430, predicted=  7, true=  1, accuracy=0.00
#
# ID=  431, predicted=  1, true=  1, accuracy=1.00
#
# ID=  432, predicted=  7, true=  7, accuracy=1.00
#
# ID=  433, predicted=  7, true=  2, accuracy=0.00
#
# ID=  434, predicted=  7, true=  7, accuracy=1.00
#
# ID=  435, predicted=  1, true=  1, accuracy=1.00
#
# ID=  436, predicted=  7, true=  6, accuracy=0.00
#
# ID=  437, predicted=  7, true=  9, accuracy=0.00
#
# ID=  438, predicted=  7, true=  2, accuracy=0.00
#
# ID=  439, predicted=  7, true=  7, accuracy=1.00
#
# ID=  440, predicted=  7, true=  3, accuracy=0.00
#
# ID=  441, predicted=  1, true=  3, accuracy=0.00
#
# ID=  442, predicted=  7, true=  2, accuracy=0.00
#
# ID=  443, predicted=  7, true=  3, accuracy=0.00
#
# ID=  444, predicted=  7, true=  2, accuracy=0.00
#
# ID=  445, predicted=  7, true=  7, accuracy=1.00
#
# ID=  446, predicted=  7, true=  7, accuracy=1.00
#
# ID=  447, predicted=  7, true=  3, accuracy=0.00
#
# ID=  448, predicted=  7, true=  8, accuracy=0.00
#
# ID=  449, predicted=  7, true=  7, accuracy=1.00
#
# ID=  450, predicted=  7, true=  7, accuracy=1.00
#
# ID=  451, predicted=  7, true=  7, accuracy=1.00
#
# ID=  452, predicted=  7, true=  3, accuracy=0.00
#
# ID=  453, predicted=  7, true=  2, accuracy=0.00
#
# ID=  454, predicted=  7, true=  2, accuracy=0.00
#
# ID=  455, predicted=  7, true=  2, accuracy=0.00
#
# ID=  456, predicted=  7, true=  3, accuracy=0.00
#
# ID=  457, predicted=  1, true=  1, accuracy=1.00
#
# ID=  458, predicted=  7, true=  2, accuracy=0.00
#
# ID=  459, predicted=  7, true=  2, accuracy=0.00
#
# ID=  460, predicted=  7, true=  7, accuracy=1.00
#
# ID=  461, predicted=  1, true=  4, accuracy=0.00
#
# ID=  462, predicted=  7, true=  7, accuracy=1.00
#
# ID=  463, predicted=  7, true=  2, accuracy=0.00
#
# ID=  464, predicted=  7, true=  2, accuracy=0.00
#
# ID=  465, predicted=  1, true=  1, accuracy=1.00
#
# ID=  466, predicted=  7, true=  3, accuracy=0.00
#
# ID=  467, predicted=  7, true=  2, accuracy=0.00
#
# ID=  468, predicted=  7, true=  7, accuracy=1.00
#
# ID=  469, predicted=  7, true=  2, accuracy=0.00
#
# ID=  470, predicted=  7, true=  7, accuracy=1.00
#
# ID=  471, predicted=  7, true=  1, accuracy=0.00
#
# ID=  472, predicted=  1, true=  1, accuracy=1.00
#
# ID=  473, predicted=  7, true=  4, accuracy=0.00
#
# ID=  474, predicted=  1, true=  8, accuracy=0.00
#
# ID=  475, predicted=  1, true=  1, accuracy=1.00
#
# ID=  476, predicted=  7, true=  1, accuracy=0.00
#
# ID=  477, predicted=  7, true=  1, accuracy=0.00
#
# ID=  478, predicted=  7, true=  1, accuracy=0.00
#
# ID=  479, predicted=  7, true=  5, accuracy=0.00
#
# ID=  480, predicted=  7, true=  3, accuracy=0.00
#
# ID=  481, predicted=  7, true=  2, accuracy=0.00
#
# ID=  482, predicted=  1, true=  8, accuracy=0.00
#
# ID=  483, predicted=  7, true=  2, accuracy=0.00
#
# ID=  484, predicted=  7, true=  1, accuracy=0.00
#
# classification accuracy=0.3595
